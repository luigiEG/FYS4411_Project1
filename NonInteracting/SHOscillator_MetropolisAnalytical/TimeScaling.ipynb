# %%
# import numpy and exp mat
import os
import numpy as np
import matplotlib.pyplot as plt

from module.QuantumSystem import SHOscillator
from module.Walker import MetropolisWalker
from module.Utils import VMC

np.random.seed(0)

# %% [markdown]
# # Spherical Harmonic Oscillator without interaction, with Metropolis and analytical hamiltonian
# In this notebook we study we study the scaling of the execution time and the std of the mean energy (for an non optimal variational parameter) as function of the dimension of the system and the number of particles and fixed sampling steps.

# %% [markdown]
# ## Time and error as function of N and D
# After fixing $\alpha$ and the computational resources, we study the time of execution and the error on the mean for a non optimal value. In this way we study the performance of Metropolis algorithm with analytical hamiltonian as a integrator to be compared with other methods.

# %%
params = np.array([0.2])
warmup_steps = 50000
calibrate_steps = 50000
run_steps = 1000000

Ns = np.array([1, 2, 10, 20, 100, 200, 500])
Ds = np.array([1, 2, 3])

# energyes are a grid of energies for each N and D
energies = np.zeros((len(Ns), len(Ds)))
energies_std = np.zeros((len(Ns), len(Ds)))
times = np.zeros((len(Ns), len(Ds)))
                 

plot_dir = 'results/TimeScaling/'


# cicle on Ns and Ds and save
for i, N in enumerate(Ns):
    for j, D in enumerate(Ds):
        print('N:', N, 'D:', D)
        system = SHOscillator(N, D)
        walker = MetropolisWalker(system)
        # plot dir in the form plot_dir/N:N_D:D/
        plot_dir_temp = plot_dir+'N:'+str(N)+'_D:'+str(D)
        # if dir does not exist create it
        if not os.path.exists(plot_dir):
            os.makedirs(plot_dir)
        vmc = VMC(system, walker, params=params,    
                  warmup_steps=warmup_steps, run_steps=run_steps, 
                  calibrate_steps=calibrate_steps, acceptance_rate=0.3,
                  plot=False, plot_dir=plot_dir_temp,
                  verbose=True)
        vmc.warmup()
        vmc.calibrate()
        vmc.run()
        energies[i,j] = vmc.get_energy()
        energies_std[i,j] = vmc.get_energy_std()
        times[i,j] = vmc.get_run_time()

# save the results
np.save(plot_dir+'energies', energies)
np.save(plot_dir+'energies_std', energies_std)
np.save(plot_dir+'times', times)
np.save(plot_dir+'Ns', Ns)
np.save(plot_dir+'Ds', Ds)
# Out:
# N: 1 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.73108
# -----------------
# VMC calibrate
# -----------------
# delta: 3.814697265625
# subgroup_size: 1
# Acceptance rate: 0.289
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.337902
# Time:  0.8370645046234131
# Energy: 0.7283879035164292 +/- 0.0017833080539376984
# N: 1 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.5898
# -----------------
# VMC calibrate
# -----------------
# delta: 1.953125
# subgroup_size: 1
# Acceptance rate: 0.325
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.342014
# Time:  0.8825562000274658
# Energy: 1.4526827302688492 +/- 0.0031024407529137463
# N: 1 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.49288
# -----------------
# VMC calibrate
# -----------------
# delta: 1.5625
# subgroup_size: 1
# Acceptance rate: 0.214
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.312393
# Time:  0.9616372585296631
# Energy: 2.1717479760738896 +/- 0.004258146743835142
# N: 2 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.72976
# -----------------
# VMC calibrate
# -----------------
# delta: 3.814697265625
# subgroup_size: 1
# Acceptance rate: 0.325
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.337248
# Time:  0.9168391227722168
# Energy: 1.44691730783623 +/- 0.00412201956083504
# N: 2 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.59104
# -----------------
# VMC calibrate
# -----------------
# delta: 1.953125
# subgroup_size: 1
# Acceptance rate: 0.286
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.342255
# Time:  0.986046552658081
# Energy: 2.8969014764467222 +/- 0.0061729649481569735
# N: 2 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.49384
# -----------------
# VMC calibrate
# -----------------
# delta: 1.5625
# subgroup_size: 1
# Acceptance rate: 0.333
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.312443
# Time:  1.0663442611694336
# Energy: 4.341678905627314 +/- 0.00880810207276149
# N: 10 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.6857
# -----------------
# VMC calibrate
# -----------------
# delta: 1.7619331945484185
# subgroup_size: 3
# Acceptance rate: 0.365
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.265666
# Time:  1.5005078315734863
# Energy: 7.25698771450395 +/- 0.01778004837206642
# N: 10 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.55224
# -----------------
# VMC calibrate
# -----------------
# delta: 1.7619331945484185
# subgroup_size: 1
# Acceptance rate: 0.362
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.381111
# Time:  1.4588186740875244
# Energy: 14.525149802394658 +/- 0.03456144490080019
# N: 10 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.46222
# -----------------
# VMC calibrate
# -----------------
# delta: 0.7216878364870323
# subgroup_size: 4
# Acceptance rate: 0.365
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.285753
# Time:  1.960045337677002
# Energy: 21.762032900121014 +/- 0.043613986793351364
# N: 20 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.67136
# -----------------
# VMC calibrate
# -----------------
# delta: 0.4082482904638631
# subgroup_size: 20
# Acceptance rate: 0.269
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.424168
# Time:  2.722663164138794
# Energy: 14.50083108970754 +/- 0.026798222120386118
# N: 20 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.54062
# -----------------
# VMC calibrate
# -----------------
# delta: 0.40824829046386313
# subgroup_size: 12
# Acceptance rate: 0.299
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.379173
# Time:  3.0198850631713867
# Energy: 28.877094962362886 +/- 0.048872851015033164
# N: 20 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.4488
# -----------------
# VMC calibrate
# -----------------
# delta: 0.6378879538497861
# subgroup_size: 4
# Acceptance rate: 0.284
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.342212
# Time:  2.7571961879730225
# Energy: 43.39024164936208 +/- 0.08206973813915171
# N: 100 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.65708
# -----------------
# VMC calibrate
# -----------------
# delta: 0.4249942772355908
# subgroup_size: 38
# Acceptance rate: 0.355
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.248637
# Time:  7.73502516746521
# Energy: 72.47376800097871 +/- 0.12095773413895516
# N: 100 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.5301
# -----------------
# VMC calibrate
# -----------------
# delta: 0.21759706994462238
# subgroup_size: 75
# Acceptance rate: 0.326
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.235083
# Time:  13.555567264556885
# Energy: 145.09018867206683 +/- 0.25507697328239104
# N: 100 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.44188
# -----------------
# VMC calibrate
# -----------------
# delta: 0.1392621247645583
# subgroup_size: 80
# Acceptance rate: 0.27
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.336491
# Time:  26.102254152297974
# Energy: 217.3482046820306 +/- 0.37580655551473574
# N: 200 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.65476
# -----------------
# VMC calibrate
# -----------------
# delta: 0.15386436372416593
# subgroup_size: 200
# Acceptance rate: 0.401
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.331032
# Time:  27.55456829071045
# Energy: 144.7168418933449 +/- 0.24473683615455535
# N: 200 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.52638
# -----------------
# VMC calibrate
# -----------------
# delta: 0.1538643637241659
# subgroup_size: 160
# Acceptance rate: 0.328
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.219706
# Time:  34.91484069824219
# Energy: 290.1579475327906 +/- 0.44213245443371224
# N: 200 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.44026
# -----------------
# VMC calibrate
# -----------------
# delta: 0.12309149097933272
# subgroup_size: 155
# Acceptance rate: 0.307
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.235001
# Time:  38.47416377067566
# Energy: 433.3710470787326 +/- 0.7698767667561015
# N: 500 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.65784
# -----------------
# VMC calibrate
# -----------------
# delta: 0.18948987444002283
# subgroup_size: 104
# Acceptance rate: 0.268
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.389715
# Time:  40.93681859970093
# Energy: 361.4556443748664 +/- 0.6778101598096048
# N: 500 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.5248
# -----------------
# VMC calibrate
# -----------------
# delta: 0.12127351964161454
# subgroup_size: 204
# Acceptance rate: 0.376
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.274342
# Time:  68.17103314399719
# Energy: 724.9747875506207 +/- 1.441022341636113
# N: 500 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.44376
# -----------------
# VMC calibrate
# -----------------
# delta: 0.09701881571329164
# subgroup_size: 130
# Acceptance rate: 0.295
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.391894
# Time:  65.0235276222229
# Energy: 1085.8847228712914 +/- 1.5099924479937905

# %%
# show the time scaling usign a matrix
plt.figure()
plt.gca().set_aspect('equal', adjustable='box')

plt.imshow(times, origin='lower')
# add the axis
plt.xticks(np.arange(len(Ds)), Ds)
plt.yticks(np.arange(len(Ns)), Ns)
# add the colorbar with units [sec]
plt.colorbar(label='sec')
plt.xlabel('D')
plt.ylabel('N')
plt.title('Execution time')
# Out:
# Text(0.5, 1.0, 'Execution time')

# %%
# show in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(Ds, Ns)
ax.plot_surface(X, Y, times, cmap='viridis')
