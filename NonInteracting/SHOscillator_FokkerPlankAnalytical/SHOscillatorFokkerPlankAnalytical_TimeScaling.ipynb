# %%
# import numpy and exp mat
import os
import numpy as np
import matplotlib.pyplot as plt

from module.QuantumSystem import SHOscillator
from module.Walker import FokkerPlankWalker
from module.Utils import VMC

np.random.seed(0)

# %% [markdown]
# # Spherical Harmonic Oscillator without interaction, with FokkerPlankWalker and analytical hamiltonian
# In this notebook we study we study the scaling of the execution time and the std of the mean energy (for an non optimal variational parameter) as function of the dimension of the system and the number of particles and fixed sampling steps.

# %% [markdown]
# ## Time and error as function of N and D
# After fixing $\alpha$ and the computational resources, we study the time of execution and the error on the mean for a non optimal value. In this way we study the performance of FokkerPlankWalker algorithm with analytical hamiltonian as a integrator to be compared with other methods.

# %%
params = np.array([0.2])
warmup_steps = 50000
calibrate_steps = 50000
run_steps = 1000000

Ns = np.array([1, 2, 10, 20, 100, 200, 500])
Ds = np.array([1, 2, 3])

# energyes are a grid of energies for each N and D
energies = np.zeros((len(Ns), len(Ds)))
energies_std = np.zeros((len(Ns), len(Ds)))
times = np.zeros((len(Ns), len(Ds)))
                 

plot_dir = 'results/TimeScaling/'


# cicle on Ns and Ds and save
for i, N in enumerate(Ns):
    for j, D in enumerate(Ds):
        print('N:', N, 'D:', D)
        system = SHOscillator(N, D)
        walker = FokkerPlankWalker(system)
        # plot dir in the form plot_dir/N:N_D:D/
        plot_dir_temp = plot_dir+'N:'+str(N)+'_D:'+str(D)
        # if dir does not exist create it
        if not os.path.exists(plot_dir):
            os.makedirs(plot_dir)
        vmc = VMC(system, walker, params=params,    
                  warmup_steps=warmup_steps, run_steps=run_steps, 
                  calibrate_steps=calibrate_steps, acceptance_rate=0.57,
                  plot=False, plot_dir=plot_dir_temp,
                  verbose=True)
        vmc.warmup()
        vmc.calibrate()
        vmc.run()
        energies[i,j] = vmc.get_energy()
        energies_std[i,j] = vmc.get_energy_std()
        times[i,j] = vmc.get_run_time()

# save the results
np.save(plot_dir+'energies', energies)
np.save(plot_dir+'energies_std', energies_std)
np.save(plot_dir+'times', times)
np.save(plot_dir+'Ns', Ns)
np.save(plot_dir+'Ds', Ds)
# Out:
# N: 1 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.94758
# -----------------
# VMC calibrate
# -----------------
# delta: 0.6938893903907228
# subgroup_size: 1
# Acceptance rate: 0.579
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.572044
# Time:  1.1961009502410889
# Energy: 0.7269261369715356 +/- 0.0045164156925172295
# N: 1 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.9104
# -----------------
# VMC calibrate
# -----------------
# delta: 0.3552713678800501
# subgroup_size: 1
# Acceptance rate: 0.588
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.516835
# Time:  1.2361869812011719
# Energy: 1.442380649922313 +/- 0.007499544444381402
# N: 1 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.88866
# -----------------
# VMC calibrate
# -----------------
# delta: 0.18189894035458565
# subgroup_size: 1
# Acceptance rate: 0.535
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.549307
# Time:  1.4278068542480469
# Energy: 2.174745993683922 +/- 0.009942267501764737
# N: 2 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.94292
# -----------------
# VMC calibrate
# -----------------
# delta: 0.6938893903907228
# subgroup_size: 1
# Acceptance rate: 0.575
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.571212
# Time:  1.2613089084625244
# Energy: 1.450873973427252 +/- 0.00841914849850606
# N: 2 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.91412
# -----------------
# VMC calibrate
# -----------------
# delta: 0.2842170943040401
# subgroup_size: 1
# Acceptance rate: 0.606
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.559204
# Time:  1.4362585544586182
# Energy: 2.922921305033567 +/- 0.01569896652123838
# N: 2 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.88306
# -----------------
# VMC calibrate
# -----------------
# delta: 0.18189894035458565
# subgroup_size: 1
# Acceptance rate: 0.61
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.549106
# Time:  1.79744291305542
# Energy: 4.339575705356082 +/- 0.020178420452166394
# N: 10 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.88276
# -----------------
# VMC calibrate
# -----------------
# delta: 0.0476837158203125
# subgroup_size: 8
# Acceptance rate: 0.622
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.594479
# Time:  2.4765403270721436
# Energy: 7.223054763089986 +/- 0.032165306869873955
# N: 10 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.83226
# -----------------
# VMC calibrate
# -----------------
# delta: 0.22737367544323206
# subgroup_size: 1
# Acceptance rate: 0.587
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.600675
# Time:  2.344581127166748
# Energy: 14.442499715760993 +/- 0.0774293705442612
# N: 10 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.797
# -----------------
# VMC calibrate
# -----------------
# delta: 0.03814697265625
# subgroup_size: 4
# Acceptance rate: 0.6
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.555578
# Time:  2.9446051120758057
# Energy: 21.70731713520107 +/- 0.10187102524133554
# N: 20 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.86266
# -----------------
# VMC calibrate
# -----------------
# delta: 0.0476837158203125
# subgroup_size: 10
# Acceptance rate: 0.594
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.54907
# Time:  3.246846914291382
# Energy: 14.49292368551266 +/- 0.054011485677498056
# N: 20 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.80568
# -----------------
# VMC calibrate
# -----------------
# delta: 0.059604644775390625
# subgroup_size: 4
# Acceptance rate: 0.601
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.551557
# Time:  3.518392324447632
# Energy: 29.020929791493934 +/- 0.13883690187660147
# N: 20 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.75936
# -----------------
# VMC calibrate
# -----------------
# delta: 0.030517578125
# subgroup_size: 5
# Acceptance rate: 0.621
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.552828
# Time:  4.344022989273071
# Energy: 43.77697655488236 +/- 0.21230938187428441
# N: 100 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.78488
# -----------------
# VMC calibrate
# -----------------
# delta: 0.0244140625
# subgroup_size: 19
# Acceptance rate: 0.617
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.548739
# Time:  9.409855604171753
# Energy: 72.5151368094986 +/- 0.3100410213855589
# N: 100 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.6914
# -----------------
# VMC calibrate
# -----------------
# delta: 0.010000000000000005
# subgroup_size: 18
# Acceptance rate: 0.547
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.593618
# Time:  12.40686297416687
# Energy: 145.39632834556826 +/- 0.661862362140304
# N: 100 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.63102
# -----------------
# VMC calibrate
# -----------------
# delta: 0.015625000000000007
# subgroup_size: 8
# Acceptance rate: 0.533
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.588633
# Time:  14.16163969039917
# Energy: 216.5496890261022 +/- 0.6371105376860836
# N: 200 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.7447
# -----------------
# VMC calibrate
# -----------------
# delta: 0.012500000000000011
# subgroup_size: 28
# Acceptance rate: 0.544
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.600525
# Time:  17.29351806640625
# Energy: 143.99760219607262 +/- 0.5796621298888952
# N: 200 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.64386
# -----------------
# VMC calibrate
# -----------------
# delta: 0.015625000000000007
# subgroup_size: 16
# Acceptance rate: 0.571
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.531275
# Time:  21.50153350830078
# Energy: 289.88339105091984 +/- 1.0294264894853595
# N: 200 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.5633
# -----------------
# VMC calibrate
# -----------------
# delta: 0.005120000000000003
# subgroup_size: 22
# Acceptance rate: 0.569
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.60301
# Time:  26.16629433631897
# Energy: 438.2068092088833 +/- 1.38781722515406
# N: 500 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.68216
# -----------------
# VMC calibrate
# -----------------
# delta: 0.0476837158203125
# subgroup_size: 8
# Acceptance rate: 0.539
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.594531
# Time:  35.7105188369751
# Energy: 359.55569658648903 +/- 1.2267668971069008
# N: 500 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.56388
# -----------------
# VMC calibrate
# -----------------
# delta: 0.03814697265625001
# subgroup_size: 5
# Acceptance rate: 0.622
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.590782
# Time:  45.80652070045471
# Energy: 725.1103647676399 +/- 2.260502878263334
# N: 500 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.4755
# -----------------
# VMC calibrate
# -----------------
# delta: 0.012500000000000002
# subgroup_size: 15
# Acceptance rate: 0.575
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.505986
# Time:  66.84231615066528
# Energy: 1089.2717482181968 +/- 2.2370834037896135

# %%
# show the time scaling usign a matrix
plt.figure()
plt.gca().set_aspect('equal', adjustable='box')

plt.imshow(times, origin='lower')
# add the axis
plt.xticks(np.arange(len(Ds)), Ds)
plt.yticks(np.arange(len(Ns)), Ns)
# add the colorbar with units [sec]
plt.colorbar(label='sec')
plt.xlabel('D')
plt.ylabel('N')
plt.title('Execution time')
# Out:
# Text(0.5, 1.0, 'Execution time')

# %%
# show in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(Ds, Ns)
ax.plot_surface(X, Y, times, cmap='viridis')
