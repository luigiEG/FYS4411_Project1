# %%
# import numpy and exp mat
import os
import numpy as np
import matplotlib.pyplot as plt

from module.QuantumSystem import SHOscillator
from module.Walker import MetropolisWalker
from module.Utils import VMC

np.random.seed(0)

# %% [markdown]
# # Spherical Harmonic Oscillator without interaction, with Metropolis and analytical hamiltonian
# In this notebook we study we study the scaling of the execution time and the std of the mean energy (for an non optimal variational parameter) as function of the dimension of the system and the number of particles and fixed sampling steps.

# %% [markdown]
# ## Time and error as function of N and D
# After fixing $\alpha$ and the computational resources, we study the time of execution and the error on the mean for a non optimal value. In this way we study the performance of Metropolis algorithm with analytical hamiltonian as a integrator to be compared with other methods.

# %%
params = np.array([0.2])
warmup_steps = 50000
calibrate_steps = 50000
run_steps = 1000000

Ns = np.array([1, 2, 10, 20])
Ds = np.array([1, 2, 3])

# energyes are a grid of energies for each N and D
energies = np.zeros((len(Ns), len(Ds)))
energies_std = np.zeros((len(Ns), len(Ds)))
times = np.zeros((len(Ns), len(Ds)))
                 

plot_dir = 'results/TimeScaling/'


# cicle on Ns and Ds and save
for i, N in enumerate(Ns):
    for j, D in enumerate(Ds):
        print('N:', N, 'D:', D)
        system = SHOscillator(N, D)
        walker = MetropolisWalker(system)
        # plot dir in the form plot_dir/N:N_D:D/
        plot_dir_temp = plot_dir+'N:'+str(N)+'_D:'+str(D)
        # if dir does not exist create it
        if not os.path.exists(plot_dir):
            os.makedirs(plot_dir)
        vmc = VMC(system, walker, params=params,    
                  warmup_steps=warmup_steps, run_steps=run_steps, 
                  calibrate_steps=calibrate_steps, acceptance_rate=0.3,
                  plot=False, plot_dir=plot_dir_temp,
                  verbose=True)
        vmc.warmup()
        vmc.calibrate()
        vmc.run()
        energies[i,j] = vmc.get_energy()
        energies_std[i,j] = vmc.get_energy_std()
        times[i,j] = vmc.get_run_time()

# save the results
np.save(plot_dir+'energies', energies)
np.save(plot_dir+'energies_std', energies_std)
np.save(plot_dir+'times', times)
np.save(plot_dir+'Ns', Ns)
np.save(plot_dir+'Ds', Ds)
# Out:
# N: 1 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.73164
# -----------------
# VMC calibrate
# -----------------
# delta: 4.76837158203125
# subgroup_size: 1
# Acceptance rate: 0.332
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.278615
# Time:  2.433441162109375
# Energy: 0.7234085773361187 +/- 0.001892016673574349
# N: 1 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.58954
# -----------------
# VMC calibrate
# -----------------
# delta: 2.44140625
# subgroup_size: 1
# Acceptance rate: 0.334
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.262457
# Time:  2.69087290763855
# Energy: 1.4525514071694476 +/- 0.0033825898212149464
# N: 1 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.49416
# -----------------
# VMC calibrate
# -----------------
# delta: 1.953125
# subgroup_size: 1
# Acceptance rate: 0.34
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.227885
# Time:  3.0209221839904785
# Energy: 2.1828710751357594 +/- 0.005290146006859331
# N: 2 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.72988
# -----------------
# VMC calibrate
# -----------------
# delta: 4.76837158203125
# subgroup_size: 1
# Acceptance rate: 0.351
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.279548
# Time:  2.749363899230957
# Energy: 1.4476102859838371 +/- 0.003856613960774529
# N: 2 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.59366
# -----------------
# VMC calibrate
# -----------------
# delta: 2.44140625
# subgroup_size: 1
# Acceptance rate: 0.363
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.262381
# Time:  3.618360757827759
# Energy: 2.890933678064642 +/- 0.006585193647233331
# N: 2 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.49312
# -----------------
# VMC calibrate
# -----------------
# delta: 1.5625
# subgroup_size: 1
# Acceptance rate: 0.342
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.313385
# Time:  4.3688743114471436
# Energy: 4.350447970993815 +/- 0.00889851264227968
# N: 10 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.68738
# -----------------
# VMC calibrate
# -----------------
# delta: 0.9021097956087903
# subgroup_size: 8
# Acceptance rate: 0.41
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.286899
# Time:  6.895208120346069
# Energy: 7.249747691755595 +/- 0.014456575700477809
# N: 10 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.54592
# -----------------
# VMC calibrate
# -----------------
# delta: 2.2024164931855235
# subgroup_size: 1
# Acceptance rate: 0.222
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.298421
# Time:  16.37208127975464
# Energy: 14.487989355052344 +/- 0.03330743749699375
# N: 10 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.46006
# -----------------
# VMC calibrate
# -----------------
# delta: 1.4095465556387348
# subgroup_size: 1
# Acceptance rate: 0.263
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.355097
# Time:  23.48911190032959
# Energy: 21.80900571788417 +/- 0.040457628498824956
# N: 20 D: 1
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.67046
# -----------------
# VMC calibrate
# -----------------
# delta: 0.5103103630798288
# subgroup_size: 20
# Acceptance rate: 0.193
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.319677
# Time:  17.907742977142334
# Energy: 14.48163016475279 +/- 0.027600949079134504
# N: 20 D: 2
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.54228
# -----------------
# VMC calibrate
# -----------------
# delta: 0.5103103630798288
# subgroup_size: 13
# Acceptance rate: 0.306
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.2546
# Time:  35.78502941131592
# Energy: 28.933900281591345 +/- 0.05268439385469589
# N: 20 D: 3
# -----------------
# VMC warmup
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.44582
# -----------------
# VMC calibrate
# -----------------
# delta: 0.5103103630798288
# subgroup_size: 6
# Acceptance rate: 0.402
# -----------------
# VMC run
# -----------------
# Parameters: [0.2]
# Acceptance rate: 0.34652
# Time:  62.18042588233948
# Energy: 43.57944676956382 +/- 0.0808751301490583

# %%
# show the time scaling usign a matrix
plt.figure()
plt.gca().set_aspect('equal', adjustable='box')

plt.imshow(times, origin='lower')
# add the axis
plt.xticks(np.arange(len(Ds)), Ds)
plt.yticks(np.arange(len(Ns)), Ns)
# add the colorbar with units [sec]
plt.colorbar(label='sec')
plt.xlabel('D')
plt.ylabel('N')
plt.title('Execution time')
# Out:
# Text(0.5, 1.0, 'Execution time')

# %%
# show in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(Ds, Ns)
ax.plot_surface(X, Y, times, cmap='viridis')
